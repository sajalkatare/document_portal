# %%
import os
import sys
from dotenv import load_dotenv
from langchain_community.chat_models import ChatAnthropic
from langchain_anthropic import ChatAnthropic
from utils.config_loader import load_config
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
#from langchain_openai import ChatOpenAI
from logger.custom_logger import CustomLogger
from exception.custom_exception import DocumentPortalException

# Set the working directory to the notebook's directory
notebook_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in dir() else os.getcwd()
os.chdir(notebook_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 from dotenv import load_dotenv
#       4 from langchain_community.chat_models import ChatAnthropic
# ----> 5 from utils.config_loader import load_config
#       6 from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       7 from langchain_google_genai import ChatGoogleGenerativeAI
#
# File G:\python_proj\document_portal\utils\config_loader.py:18
#      15         print(config)
#      16         return config
# ---> 18 load_config("config\config.yaml")
#
# File G:\python_proj\document_portal\utils\config_loader.py:13, in load_config(config_path)
#       3 def load_config(config_path: str = "config\config.yaml") -> dict:
#       4     """
#       5     Load configuration from a YAML file.
#       6
#    (...)
#      11         dict: The loaded configuration as a dictionary.
#      12     """
# ---> 13     with open(config_path, "r") as file:
#      14         config=yaml.safe_load(file)
#      15         print(config)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'

# %%
# %pip install langchain-anthropic

load_dotenv()

model = ChatAnthropic(model='claude-sonnet-4-5')

result = model.invoke('Who is president of venezuela?')

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_anthropic import ChatAnthropic
#       2 from dotenv import load_dotenv
#       4 load_dotenv()
#
# ModuleNotFoundError: No module named 'langchain_anthropic'
