# %%
print("----------All Done!----------")
# Out:
# ----------All Done!----------

# %%
import sys
import traceback
class DocumentPortalException(Exception):
    """Custom exception for Document Portal errors."""
    def __init__(self, error_message:str, error_details:sys):
        _,_,exe_tb = error_details.exc_info()
        self.file_name = exe_tb.tb_frame.f_code.co_filename
        self.lineno = exe_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))
    
        

    def __str__(self):
        return f"""
        Error In : {self.file_name}
        At Line Number: {self.lineno}
        Error Message: {self.error_message}
        Traceback: {self.traceback_str}
        """

if __name__ == "__main__":
    try:
        a = 1 / 0  # This will raise a ZeroDivisionError
        print(a)
    except Exception as e:
        app_exception = DocumentPortalException(e,sys)
        raise app_exception
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 24
#      23 try:
# ---> 24     a = 1 / 0  # This will raise a ZeroDivisionError
#      25     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[3], line 28
#      26 except Exception as e:
#      27     app_exception = DocumentPortalException(e,sys)
# ---> 28     raise app_exception
#
# DocumentPortalException:
#         Error In : C:\Users\user\AppData\Local\Temp\ipykernel_36748\432818291.py
#         At Line Number: 24
#         Error Message: division by zero
#         Traceback: Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_36748\432818291.py", line 24, in <module>
#     a = 1 / 0  # This will raise a ZeroDivisionError
# ZeroDivisionError: division by zero

# %% [markdown]
# ## How to log this exception in a file?

# %%
from logger.custom_logger import CustomLogger

# %%
logger = CustomLogger().get_logger("exception_experiment")

# %%
import sys
import traceback
class DocumentPortalException(Exception):
    """Custom exception for Document Portal errors."""
    def __init__(self, error_message:str, error_details:sys):
        _,_,exe_tb = error_details.exc_info()
        self.file_name = exe_tb.tb_frame.f_code.co_filename
        self.lineno = exe_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))
    
        

    def __str__(self):
        return f"""
        Error In : {self.file_name}
        At Line Number: {self.lineno}
        Error Message: {self.error_message}
        Traceback: {self.traceback_str}
        """

if __name__ == "__main__":
    try:
        a = 1 / 0  # This will raise a ZeroDivisionError
        print(a)
    except Exception as e:
        app_exception = DocumentPortalException(e,sys)
        logger.error(app_exception)
        raise app_exception
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 24
#      23 try:
# ---> 24     a = 1 / 0  # This will raise a ZeroDivisionError
#      25     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[15], line 29
#      27 app_exception = DocumentPortalException(e,sys)
#      28 logger.error(app_exception)
# ---> 29 raise app_exception
#
# DocumentPortalException:
#         Error In : C:\Users\user\AppData\Local\Temp\ipykernel_28268\400392175.py
#         At Line Number: 24
#         Error Message: division by zero
#         Traceback: Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_28268\400392175.py", line 24, in <module>
#     a = 1 / 0  # This will raise a ZeroDivisionError
# ZeroDivisionError: division by zero
